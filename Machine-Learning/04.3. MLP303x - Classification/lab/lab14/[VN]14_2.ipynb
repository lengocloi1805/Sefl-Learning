# %% [markdown]
# # SMOTE
#
# Tạo mẫu mới bằng phép ngoại suy các mẫu của lớp thiểu số và bất kỳ k neighbour gần nhất nào của nó (cũng từ lớp thiểu số). k thường là 5.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from imblearn.over_sampling import SMOTE
# Out:
# C:\Users\Admin\miniconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Admin\miniconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\Admin\miniconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Tạo dữ liệu
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# Chúng ta sẽ tạo 2 lớp: 1 lớp đa số và 1 lớp thiểu số, được phân tách rõ ràng để dễ minh họa.

# %%
# Tùy chọn cấu hình
blobs_random_seed = 42
centers = [(0, 0), (5, 5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 1600

# Tạo X
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# biến đổi mảng thành định dạng của pandas
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# tạo một tập dữ liệu X mất cân bằng
# (khiến blob tạo số lượng quan sát tương tự ở mỗi lớp
# mà chúng ta cần để giảm mẫu theo cách thủ công)
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(200, random_state=42)
], axis=0)

y = y.loc[X.index]

# hiển thị kích thước
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %% [markdown]
# ## SMOTE
#
# [SMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html)

# %%
## Yêu cầu 1:
## VIẾT CODE Ở ĐÂY:
sm = SMOTE(
    sampling_strategy='auto',  # chỉ lấy mẫu lớp thiểu số
    random_state=0,  # khả năng tái lặp
    k_neighbors=5,
    n_jobs=4
)

X_res, y_res = sm.fit_resample(X, y)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [SMOTE()](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html)
#
# </details>

# %%
# kích thước dữ liệu ban đầun đầun đầun đầun đầu

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# kích thước dữ liệu undersampled

X_res.shape, y_res.shape
# Out:
# ((1600, 2), (1600,))

# %%
# số lượng quan sát của lớp thiểu số
## Yêu cầu 2
## VIẾT CODE Ở ĐÂY:
y.value_counts(), y_res.value_counts()
# Out:
# (0    800
#  1    200
#  dtype: int64,
#  0    800
#  1    800
#  dtype: int64)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```value_counts()```
#
# </details>

# %%
# biểu đồ dữ liệu ban đầu

sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# biểu đồ dữ liệu đã chọn

sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

plt.title('Over-sampled dataset')
plt.show()

# %% [markdown]
# Các quan sát mới khác với các quan sát ban đầu.

# %% [markdown]
# **BÀI TẬP**
#
# - Kiểm tra SMOTE trong một tập dữ liệu từ imbalanced-learn và tạo một số biểu đồ của các biến làm nổi bật lớp thiểu số để hiển thị kết quả tốt hơn.
#
# - Thay đổi tham số strategy và k_neighbor ở notebook hiện tại để thu được các tỷ lệ khác nhau của lớp thiểu số và các mẫu mới khác, khám phá phân phối của chúng.

# %% [markdown]
# # SMOTE-NC
#
# Mở rộng chức năng của SMOTE tới các biến hạng mục.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from imblearn.over_sampling import SMOTENC

# %% [markdown]
# ## Tạo dữ liệu
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# Chúng ta sẽ tạo 2 lớp: 1 lớp đa số và 1 lớp thiểu số, được phân tách rõ ràng để dễ minh họa.

# %%
# Tùy chọn cấu hình
blobs_random_seed = 42
centers = [(0, 0), (5, 5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 1600

# Tạo X
## Yêu cầu 3
## VIẾT CODE Ở ĐÂY:
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# biến đổi mảng thành định dạng của pandas
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# thêm các đặc trưng hạng mục
rng = np.random.RandomState(42)
X['VarC'] = rng.choice(['A', 'B', 'C'], size=num_samples_total).astype(object)
X['VarD'] = rng.choice(['Blue', 'Green', 'Red'], size=num_samples_total).astype(object)

# tạo một tập dữ liệu X mất cân bằng
# (khiến blob tạo số lượng quan sát tương tự ở mỗi lớp
# mà chúng ta cần để giảm mẫu theo cách thủ công)
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(200, random_state=42)
], axis=0)

y = y.loc[X.index]

# hiển thị kích thước
X.shape, y.shape
# Out:
# ((1000, 4), (1000,))

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```make_blobs()```
#
# </details>

# %%
X.head()
# Out:
#        VarA      VarB VarC   VarD
# 1  1.741535  1.314719    A   Blue
# 3 -0.192193  0.052357    C    Red
# 4  0.919050 -0.683715    A   Blue
# 5  0.429876 -0.560409    A  Green
# 6  1.098259 -2.332320    C  Green

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue='VarC', alpha=0.5
)

plt.title('Toy dataset - hue by VarC')
plt.show()

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue='VarD', alpha=0.5
)

plt.title('Toy dataset - hue by VarD')
plt.show()

# %% [markdown]
# ## SMOTE-NC
#
# [SMOTENC](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTENC.html)

# %%
## Yêu cầu 4
## VIẾT CODE Ở ĐÂY:
smnc = SMOTENC(
    sampling_strategy='auto', # chỉ lấy mẫu lớp thiểu số
    random_state=0,  # khả năng tái lặp
    k_neighbors=5,
    n_jobs=4,
    categorical_features=[2,3] # chỉ số của cột có các biến hạng mục
)  

X_res, y_res = smnc.fit_resample(X, y)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [SMOTENC()](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTENC.html)
#
# </details>

# %%
# kích thước dữ liệu ban đầu

X.shape, y.shape
# Out:
# ((1000, 4), (1000,))

# %%
# kích thước dữ liệu undersampled

X_res.shape, y_res.shape
# Out:
# ((1600, 4), (1600,))

# %%
# số lượng quan sát của lớp thiểu số
## Yêu cầu 5
## VIẾT CODE Ở ĐÂY:
y.value_counts(), y_res.value_counts()
# Out:
# (0    800
#  1    200
#  dtype: int64,
#  0    800
#  1    800
#  dtype: int64)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```value_counts()```
#
# </details>

# %%
X.tail()
# Out:
#           VarA      VarB VarC   VarD
# 202   5.317105  3.836910    A  Green
# 1323  4.886993  4.157280    C   Blue
# 397   6.325630  5.041558    C  Green
# 1581  5.633563  5.995463    B   Blue
# 1132  6.937695  5.336812    C    Red

# %%
X_res.tail()
# Out:
#           VarA      VarB VarC  VarD
# 1595  4.341677  5.792416    A   Red
# 1596  4.681074  2.353727    B  Blue
# 1597  4.821497  4.065280    A   Red
# 1598  4.844482  5.519909    A   Red
# 1599  4.094833  4.032585    B  Blue

# %%
# biểu đồ dữ liệu ban đầu
## Yêu cầu 6
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue = y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# biểu đồ dữ liệu đã chọn
## Yêu cầu 7
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

plt.title('Over-sampled dataset')
plt.show()

# %% [markdown]
# Các quan sát mới khác với các quan sát ban đầu.

# %% [markdown]
# **BÀI TẬP**
#
# - Kiểm tra SMOTENC trong một tập dữ liệu của riêng bạn có cả biến dạng số và biến hạng mục. Hãy xem liệu nó có cải thiện chất lượng mô hình không.
#
# - Nếu không có cải thiện gì, hãy thử với strategy và số lượng neighbour.

# %% [markdown]
# # SMOTE đường biên (BorderlineSMOTE)
#
# Tạo mẫu mới bằng cách nội suy mẫu của lớp đa số và các neighbour gần nhất của nó. Nó không sử dụng toàn bộ quan sát của lớp thiểu số làm khuôn mẫu giống như SMOTE, mà trước tiên nó sẽ chọn các quan sát có phần lớn neighbour thuộc lớp đa số rồi dùng chúng làm khuôn mẫu để tạo dữ liệu tổng hợp.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from imblearn.over_sampling import BorderlineSMOTE

# %% [markdown]
# ## Tạo dữ liệu
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# Chúng ta sẽ tạo 2 lớp: 1 lớp đa số và 1 lớp thiểu số, được phân tách rõ ràng để dễ minh họa.

# %%
# Tùy chọn cấu hình
blobs_random_seed = 42
centers = [(0, 0), (5, 5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 1600

# Tạo X
## Yêu cầu 8
## VIẾT CODE Ở ĐÂY:
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# biến đổi mảng thành định dạng của pandas
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# tạo một tập dữ liệu X mất cân bằng
# (khiến blob tạo số lượng quan sát tương tự ở mỗi lớp
# mà chúng ta cần để giảm mẫu theo cách thủ công)
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(200, random_state=42)
], axis=0)

y = y.loc[X.index]

# hiển thị kích thước
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```make_blobs()```
#
# </details>

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %% [markdown]
# ## BorderlineSMOTE
#
# [BorderlineSMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.BorderlineSMOTE.html)

# %%
## Yêu cầu 9
## VIẾT CODE Ở ĐÂY:
sm_b1 = BorderlineSMOTE(
    sampling_strategy='auto',  # chỉ lấy mẫu lớp thiểu số
    random_state=0,  # khả năng tái lặp
    k_neighbors=5,
    m_neighbors=10,
    kind='borderline-1',
    n_jobs=4
)

X_res_b1, y_res_b1 = sm_b1.fit_resample(X, y)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [BorderlineSMOTE()](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.BorderlineSMOTE.html)
#
# </details>

# %%
## Yêu cầu 10
## VIẾT CODE Ở ĐÂY:
sm_b2 = BorderlineSMOTE(
    sampling_strategy='auto',  # chỉ lấy mẫu lớp thiểu số
    random_state=0,  # khả năng tái lặp
    k_neighbors=5,
    m_neighbors=10,
    kind='borderline-2',
    n_jobs=4
)

X_res_b2, y_res_b2 = sm_b2.fit_resample(X, y)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [BorderlineSMOTE()](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.BorderlineSMOTE.html)
#
# </details>

# %%
# kích thước dữ liệu ban đầu

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# kích thước dữ liệu undersampled

X_res_b1.shape, y_res_b1.shape
# Out:
# ((1600, 2), (1600,))

# %%
# kích thước dữ liệu undersampled

X_res_b2.shape, y_res_b2.shape
# Out:
# ((1599, 2), (1599,))

# %%
# số lượng quan sát của lớp thiểu số
## Yêu cầu 11
## VIẾT CODE Ở ĐÂY:
y.value_counts(), y_res_b1.value_counts(), y_res_b2.value_counts()
# Out:
# (0    903
#  1    297
#  dtype: int64,
#  0    800
#  1    800
#  dtype: int64,
#  0    800
#  1    799
#  dtype: int64)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```value_counts()```
#
# </details>

# %%
# biểu đồ dữ liệu ban đầu
## Yêu cầu 12
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# biểu đồ dữ liệu đã chọn
## Yêu cầu 13
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X_res_b1, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Borderline SMOTE variant 1')
plt.show()

# %%
# biểu đồ dữ liệu đã chọn
## Yêu cầu 14
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X_res_b2, x="VarA", y="VarB", hue=y_res_b2, alpha=0.5
)

plt.title('Borderline SMOTE variant 2')
plt.show()

# %% [markdown]
# Chúng ta thấy rằng nếu sử dụng variant 2 thì chúng ta sẽ tạo ra nhiều dữ liệu tổng hợp hơn hướng tới lớp đa số.

# %% [markdown]
# **BÀI TẬP**
#
# - Kiểm tra SMOTE đường biên sử dụng tập dữ liệu giả lập mà chúng ta đã tạo và xem phân phối của dữ liệu mới tạo thay đổi thế nào với các phân tách lớp khác nhau.

# %% [markdown]
# # SVM-SMOTE
#
# Tạo mẫu mới bằng cách nội suy các mẫu của vectơ hỗ trợ từ lớp thiểu số và các neighbour gần nhất của nó.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from sklearn import svm

from imblearn.over_sampling import SVMSMOTE

# %% [markdown]
# ## Tạo dữ liệu
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# Chúng ta sẽ tạo 2 lớp: 1 lớp đa số và 1 lớp thiểu số, được phân tách rõ ràng để dễ minh họa.

# %%
# Tùy chọn cấu hình
blobs_random_seed = 42
centers = [(0, 0), (5, 5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 1600

# Tạo X
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# biến đổi mảng thành định dạng của pandas
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# tạo một tập dữ liệu X mất cân bằng
# (khiến blob tạo số lượng quan sát tương tự ở mỗi lớp
# mà chúng ta cần để giảm mẫu theo cách thủ công)
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(200, random_state=42)
], axis=0)

y = y.loc[X.index]

# hiển thị kích thước
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %% [markdown]
# ## Tìm vectơ hỗ trợ

# %%
# Khởi tạo bộ phân loại SVM
## Yêu cầu 15
## VIẾT CODE Ở ĐÂY:
clf = svm.SVC(kernel='linear')

# Khớp dữ liệu
clf = clf.fit(X, y)

# vectơ hỗ trợ, chỉ số 
clf.support_
# Out:
# array([ 54, 150, 225, 226, 273, 346, 390, 428, 458, 572, 607, 692, 854,
#        873, 894, 903, 906, 913, 915, 924, 969, 976, 998])

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [SVC()](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)
#
# </details>

# %%
# số lượng vectơ hỗ trợ
## Yêu cầu 16
## VIẾT CODE Ở ĐÂY:
len(clf.support_)
# Out:
# 23

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```support_```
#
# </details>

# %%
# vectơ hỗ trợ
## Yêu cầu 17
## VIẾT CODE Ở ĐÂY:
clf.support_vectors_
# Out:
# array([[1.46447342, 3.91708081],
#        [1.77981973, 4.86223665],
#        [2.36662115, 3.17847039],
#        [1.28605973, 4.09323048],
#        [2.754491  , 3.60300648],
#        [3.50738906, 1.64116879],
#        [3.10799934, 3.99247222],
#        [3.21723103, 2.28937153],
#        [2.45614284, 3.17017763],
#        [4.14699994, 2.0985245 ],
#        [2.94611183, 2.92465437],
#        [4.39266913, 1.02919853],
#        [2.85647812, 3.80456733],
#        [2.55056653, 4.16844874],
#        [3.26552849, 3.28801023],
#        [2.49339863, 2.48924471],
#        [1.12886071, 4.57011622],
#        [4.48343244, 1.69442608],
#        [3.49223192, 2.3883134 ],
#        [3.39594514, 3.2227212 ],
#        [3.72714096, 2.82986121],
#        [3.02416386, 3.30304906],
#        [2.06406965, 3.95758943]])

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# Sử dụng ```support_vectors_```
#
# </details>

# %%
# đánh dấu các vectơ hỗ trợ

sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.scatter(clf.support_vectors_[:,0],
            clf.support_vectors_[:, 1],
            s=100,
            linewidth=1,
            facecolors='none',
            edgecolors='k')

# %%
# vẽ biểu đồ ranh giới quyết định
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# thêm ranh giới quyết định
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 50),
                     np.linspace(ylim[0], ylim[1], 50))

# decision_function
Z = np.dot(np.c_[xx.ravel(), yy.ravel()], clf.coef_[0]) + clf.intercept_[0]
Z = Z.reshape(xx.shape)
    
plt.contour(xx, yy, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
                linestyles=['--', '-', '--'])

# %% [markdown]
# ## SVM SMOTE
#
# [SVMSMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SVMSMOTE.html)

# %%
## Yêu cầu 18
## VIẾT CODE Ở ĐÂY:
sm = SVMSMOTE(
    sampling_strategy='auto',  # chỉ lấy mẫu lớp thiểu số
    random_state=0,  # khả năng tái lặp
    k_neighbors=5,
    m_neighbors=10,
    n_jobs=4,
    svm_estimator = svm.SVC(kernel='linear')
)

X_res, y_res = sm.fit_resample(X, y)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [SVMSMOTE()](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SVMSMOTE.html)
#
# </details>

# %%
# kích thước dữ liệu ban đầu

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# kích thước dữ liệu undersampled

X_res.shape, y_res.shape
# Out:
# ((1600, 2), (1600,))

# %%
# số lượng quan sát của lớp thiểu số

y.value_counts(), y_res.value_counts()
# Out:
# (0    800
#  1    200
#  dtype: int64,
#  0    800
#  1    800
#  dtype: int64)

# %%
# biểu đồ dữ liệu ban đầu
## Yêu cầu 19
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# biểu đồ dữ liệu ban đầu
## Yêu cầu 20
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

plt.title('SVM SMOTE')
plt.show()

# %%
# biểu đồ dữ liệu đã chọn

sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# thêm ranh giới quyết định
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 50),
                     np.linspace(ylim[0], ylim[1], 50))

# decision_function
Z = np.dot(np.c_[xx.ravel(), yy.ravel()], clf.coef_[0]) + clf.intercept_[0]
Z = Z.reshape(xx.shape)
    
plt.contour(xx, yy, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
                linestyles=['--', '-', '--'])

plt.title('SVM SMOTE with support vectors')
plt.show()

# %% [markdown]
# Chúng ta thấy rằng đa số các mẫu tổng hợp được tạo gần hơn với các vectơ hỗ trợ từ lớp thiểu số.

# %% [markdown]
# **BÀI TẬP**
#
# - Kiểm tra SVM SMOTE sử dụng tập dữ liệu giả lập mà chúng ta đã tạo và xem phân phối của dữ liệu mới tạo thay đổi thế nào với các phân tách lớp khác nhau.

# %% [markdown]
# # K-Means SMOTE
#
# Tạo mẫu mới bằng cách nội suy các mẫu với SMOTE trong các cụm đã chọn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

from imblearn.over_sampling import KMeansSMOTE

# %% [markdown]
# ## Tạo dữ liệu
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html
#
# Chúng ta sẽ tạo 2 lớp: 1 lớp đa số và 1 lớp thiểu số, được phân tách rõ ràng để dễ minh họa.

# %%
# Tùy chọn cấu hình
blobs_random_seed = 42
centers = [(0, 0), (5, 5), (0,5)]
cluster_std = 1.5
num_features_for_samples = 2
num_samples_total = 2100

# Tạo X
X, y = make_blobs(
    n_samples=num_samples_total,
    centers=centers,
    n_features=num_features_for_samples,
    cluster_std=cluster_std)

# biến đổi mảng thành định dạng của pandas
X = pd.DataFrame(X, columns=['VarA', 'VarB'])
y = pd.Series(y)

# số mẫu trên blob khác nhau
X = pd.concat([
    X[y == 0],
    X[y == 1].sample(400, random_state=42),
    X[y == 2].sample(100, random_state=42)
], axis=0)

y = y.loc[X.index]

# đặt lại index
X.reset_index(drop=True, inplace=True)
y.reset_index(drop=True, inplace=True)

             
# tạo mục tiêu mất cân bằng
y = pd.concat([
    pd.Series(np.random.binomial(1, 0.3, 700)),
    pd.Series(np.random.binomial(1, 0.2, 400)),
    pd.Series(np.random.binomial(1, 0.1, 100)),
], axis=0).reset_index(drop=True)

# hiển thị kích thước
X.shape, y.shape
# Out:
# ((1200, 2), (1200,))

# %%
y.value_counts()
# Out:
# 0    863
# 1    337
# dtype: int64

# %%
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y, alpha=0.5
)

plt.title('Toy dataset')
plt.show()

# %% [markdown]
# ## K-Means SMOTE
#
# [KMeansSMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.KMeansSMOTE.html)

# %%
## Yêu cầu 21
## VIẾT CODE Ở ĐÂY:
sm = KMeansSMOTE(
    sampling_strategy='auto',  # chỉ lấy mẫu lớp thiểu số
    random_state=0,  # khả năng tái lặp
    k_neighbors=2,
    n_jobs=None,
    kmeans_estimator=KMeans(n_clusters=3, random_state=0),
    cluster_balance_threshold=0.1,
    density_exponent='auto'
)

X_res, y_res = sm.fit_resample(X, y)

# %% [markdown]
# <details><summary> Gợi ý </summary>
#
# [KMeansSMOTE()](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.KMeansSMOTE.html)
#
# </details>

# %%
# kích thước dữ liệu ban đầu

X.shape, y.shape
# Out:
# ((1200, 2), (1200,))

# %%
# kích thước dữ liệu undersampled

X_res.shape, y_res.shape
# Out:
# ((1727, 2), (1727,))

# %%
# số lượng quan sát của lớp thiểu số

y.value_counts(), y_res.value_counts()
# Out:
# (0    863
#  1    337
#  dtype: int64,
#  1    864
#  0    863
#  dtype: int64)

# %%
# biểu đồ dữ liệu ban đầu
## Yêu cầu 22
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X, x="VarA", y="VarB", hue=y,alpha=0.5
)

plt.title('Original dataset')
plt.show()

# %%
# biểu đồ dữ liệu đã chọn
## Yêu cầu 23
## VIẾT CODE Ở ĐÂY:
sns.scatterplot(
    data=X_res, x="VarA", y="VarB", hue=y_res, alpha=0.5
)

plt.title('K-Means SMOTE')
plt.show()
